# %%
# basic library
import pandas as pd
import numpy as np
import json

# Eda libr
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
from scipy.stats import spearmanr,pearsonr
from scipy.stats import norm
from scipy import stats
import pylab
import plotly.express as px
import scipy.stats as st
# %matplotlib inline

# Remove Warnings
import warnings
warnings.filterwarnings('ignore')

# Split the Data Train and Test
from sklearn.model_selection import train_test_split

# Models Building
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import ExtraTreesClassifier


# Scaling and Normalization 
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler

# Label Encoding 
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# Model Evaluation 
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report

# Learning Curuve
from sklearn.model_selection import learning_curve

# Stats-Model and Vif
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# cross Validation
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# Optimization
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# Feature Selection
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import RFE

# Make PipeLine
from sklearn.pipeline import make_pipeline

# Dime Reduction
from sklearn.decomposition import PCA

# Date and Time
import datetime
import time

import tqdm
from tqdm import tqdm_notebook



# Decision Tree 
from sklearn.tree import export_graphviz
import pydotplus
from six import StringIO 
from IPython.display import Image

import sklearn

from numpy import mean
from numpy import std
from sklearn.model_selection import RepeatedStratifiedKFold
from matplotlib import pyplot
from numpy import arange

import spacy
import re
import spacy
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
import re
from string import punctuation
import en_core_web_sm
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

nlp = en_core_web_sm.load()

stop_words = ['the','a','an','and','but','if','or','because','as','what','which','this','that','these','those','then',
              'just','so','than','such','both','through','about','for','is','of','while','during','to','What','Which',
              'Is','If','While','This']

import nltk
stopwords = nltk.download('stopwords')
from textblob import TextBlob 
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
import string
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, preprocessing, metrics, linear_model, svm
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from imblearn.over_sampling import BorderlineSMOTE, SMOTE, ADASYN, SMOTENC, RandomOverSampler
from imblearn.under_sampling import (RandomUnderSampler, 
                                    NearMiss, 
                                    InstanceHardnessThreshold,
                                    CondensedNearestNeighbour,
                                    EditedNearestNeighbours,
                                    RepeatedEditedNearestNeighbours,
                                    AllKNN,
                                    NeighbourhoodCleaningRule,
                                    OneSidedSelection,
                                    TomekLinks)
from imblearn.combine import SMOTEENN, SMOTETomek
from imblearn.pipeline import make_pipeline
import pandas as pd, numpy, string
from nltk.tokenize import WordPunctTokenizer
from nltk.stem import PorterStemmer
#Remove Special Charactors
import re
from nltk.tokenize import WordPunctTokenizer
from nltk.stem import PorterStemmer
import unidecode
import string
import random
import urllib.request
from collections import Counter
from nltk import word_tokenize
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer,PorterStemmer
from nltk.corpus import stopwords
import re
import urllib.request
from collections import Counter
from nltk import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer
import optuna 
from optuna import Trial, visualization
from optuna.samplers import TPESampler

for i in tqdm_notebook(range(10), desc = "ALL Libraries For Model"):
    time.sleep(0.1)


print("All Libraries Imported")
print(" ")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Charan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# HBox(children=(HTML(value='ALL Libraries For Model'), FloatProgress(value=0.0, max=10.0), HTML(value='')))
# All Libraries Imported

# %%
def data_head(df):
    return df.head()

def data_tail(df):
    return df.tail()

def data_1_to_20(df):
    return df.head(n = 20)

def data_missing_with_missing_go(df):
    msno.matrix(df,figsize=(12,6))
    plt.show()
    
def data_missing_heat_map(df):
    plt.figure(figsize=(12,6))
    sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
    plt.show()
    
def data_missing_heat_map2(df):
    plt.figure(figsize=(12,6))
    sns.heatmap(df.notna())
    plt.show()
    
def data_missing(df):
    return df.isnull().sum()

def data_missing2(df):
    for col in df.columns:
        a =df[col].isnull().sum()
        print(col,a)
        print(" ")

def data_missing_columns(df):
    return df.columns[df.isnull().any()]

def data_missing_values_percentage(df):
    total = df.isnull().sum().sort_values(ascending=False)
    percent = ((df.isnull().sum())*100)/df.isnull().count().sort_values(ascending=False)
    missing_data=pd.concat([total, percent], axis=1, keys=['Total','Percent'], sort=False).sort_values('Total', ascending=False)
    print(missing_data)
    
def data_missing_values_percentage2(df):
    return df.isnull().mean()
    
def data_missing__values_barplot(data):
    total = data.isnull().sum().sort_values(ascending = False)
    percent = (data.isnull().sum()/data.isnull().count()*100).sort_values(ascending = False)
    ms=pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
    ms= ms[ms["Percent"] > 0]
    f,ax =plt.subplots(figsize=(8,6))
    plt.xticks(rotation='90')
    fig=sns.barplot(ms.index, ms["Percent"],color="green",alpha=0.8)
    plt.xlabel('Features', fontsize=15)
    plt.ylabel('Percent of missing values', fontsize=15)
    plt.title('Percent missing data by feature', fontsize=15)
    return ms

def data_missing__values_barplot2(df):
    missing_df = df.isnull().sum(axis=0).reset_index()
    missing_df.columns = ['column_name', 'missing_count']
    missing_df = missing_df.loc[missing_df['missing_count']>0]
    missing_df = missing_df.sort_values(by='missing_count')

    ind = np.arange(missing_df.shape[0])
    width = 0.9
    fig, ax = plt.subplots(figsize=(10,8))
    rects = ax.barh(ind, missing_df.missing_count.values, color='blue')
    ax.set_yticks(ind)
    ax.set_yticklabels(missing_df.column_name.values, rotation='horizontal')
    ax.set_xlabel("Count of missing values")
    ax.set_title("Number of missing values in each column")
    plt.show()
    
def data_data_types(df):
    return df.dtypes
    
def data_table_describe(df):
    return df.describe()

def data_describe_each_feature(df):
    for col in df[num]:
        mask = df[col].describe()
        print(col,"\n",mask)
        print(" ")

def data_table_corr(df):
    return df.corr()

def data_info(df):
    return df.info()

def data_shape(df):
    return df.shape

def data_data_frame_Transpose(df):
    return df.T

def data_index(df):
    return df.index

def data_count(df):
    return df.count()

def data_display_all_rows_and_columns(df):
    pd.set_option('display.max_columns', None)
    pd.set_option('display.max_rows', None)

def data_num_and_cat(df):
    cat = []
    num = []
    for col in df.columns:
        if df[col].dtype=='O':
            cat.append(col)
        else:
            num.append(col)
    return num,cat

def data_heatmap(df):
    plt.figure(figsize=(18,11))
    sns.heatmap(df.corr(),annot=True,cmap='Reds')
    plt.show()
    
def data_heatmap2(df):
    plt.figure(figsize=(18,11))
    sns.heatmap(df.corr(),annot=True,cmap='Blues')
    plt.show()

def data_heatmap3(df):
    plt.figure(figsize=(18,11))
    sns.heatmap(df.corr(),annot=True,cmap='YlGnBu')
    plt.show()
    
def data_heatmap_no_annot(df):
    plt.figure(figsize=(18,11))
    sns.heatmap(df.corr(),annot=False,cmap='Reds')
    plt.show()
    
def data_heatmap_no_annot2(df):
    plt.figure(figsize=(18,11))
    sns.heatmap(df.corr(),annot=False,cmap='viridis')
    plt.show()
    
def data_heat_map_other(df):
    plt.figure(figsize=(18,11))
    return (df.corr().style.background_gradient(cmap='coolwarm'))

def data_heat_map_other2(df):
    corr = df.corr()
    cut_off = 0.1
    corr = corr[(corr > cut_off) | (corr < -cut_off)]
    plt.subplots(figsize=(18,11));
    sns.heatmap(corr, cmap="RdBu", square=True, annot=False, cbar_kws={"shrink": .6}, )
    plt.title(f"Correlation of features greater than +/-{cut_off}")
    plt.tight_layout()
    plt.show()
    
def data_heat_map_other3(df):
    corrMatt = df.corr()
    mask = np.array(corrMatt)
    mask[np.tril_indices_from(mask)] = False
    fig,ax= plt.subplots()
    fig.set_size_inches(18,11)
    sns.heatmap(corrMatt, mask=mask,vmax=.8, square=True,annot=True)
    plt.show()
    
def data_check_corr(df):
    corr = df.corr()
    plt.figure(figsize=(16,9));
    corr["response"].sort_values(ascending=True)[:-1].plot(kind="barh")
    plt.xlabel("Correlation")
    plt.tight_layout()
    plt.show()
    
def data_check_corr2(df):
    labels = []
    values = []
    for col in df:
        if col not in ["response"]:
            labels.append(col)
            values.append(spearmanr(df[col].values, df["response"].values)[0])
    corr_df = pd.DataFrame({'col_labels':labels, 'corr_values':values})
    corr_df = corr_df.sort_values(by='corr_values')
    ind = np.arange(corr_df.shape[0])
    width = 0.9
    fig, ax = plt.subplots(figsize=(12,15))
    rects = ax.barh(ind, np.array(corr_df.corr_values.values), color='g')
    ax.set_yticks(ind)
    ax.set_yticklabels(corr_df.col_labels.values, rotation='horizontal')
    ax.set_xlabel("Correlation coefficient")
    ax.set_title("Correlation coefficient of the variables")
    plt.show()
    
def data_heat_map_cluster_map(df):
    sns.clustermap(df.corr(), annot=True, linewidths=.6, fmt= '.2f', figsize=(15, 10))
    plt.show()
    
def data_data_info(df):
    return df.info()
        
def data_display_all_columns(df):
    return (df.columns)

def data_df_size(df):
    for col in df.columns:
        print(col,df[col].size)
        print(" ")
    return print("Total size of Data_Frame ",df.size)

def data_check_unique_featues_columns(df):
    for col in df.columns:
        print('variable',col,' has unique elemnts  \n',len(df[col].unique()))
        print(" \n" )
    print('Total Number of Elements \n',len(df))
    
def data_print_unique_features(df):
    for col in df.columns:
        print('variable',col,' its unique elemnts  \n',df[col].unique())
        print(" \n ")
        
def data_display_unique_features_with_size(df):
    for col in df.columns:
        print(" \n ")
        print(col,len(df[col].unique()))
        print(" ")
        print(df[col].unique()[:30])
        print(" ")
        
def data_value_counts_all_columns(df):
    for col in df.columns:
        x = df[col].value_counts()
        print("Column name is:",col,"and it value is:",x)
        print(" \n ")
        
def data_show_valuecounts_perc(df):
    for col in df.columns:
        print(col,df[col].value_counts() / len(df))
        print(" ")
        
def data_value_counts_bins(df):
    for col in df.columns:
        return df[col].value_counts(bins = 5, ascending = True)
    
def data_value_counts_bins2(df):
    for col in df.columns:
        return df[col].value_counts(bins = 10, ascending = True)
    
def data_data_sort_values(df):
    for col in df.columns:
        print(col,df[col].sort_values())
        print(" ")
        
def data_data_rank(df):
    for col in df.columns:
        print(col,df[col].rank())
        print(" ")

# works with numeric features
def data_nunique(df):
    for col in df.columns:
        print(col,df[col].nunique())
        print(" ")
        
def data_nlargest(df):
    for col in df[num].columns:
        print(col,"\n",df.nlargest(10,col))
        print(" ")
        
def data_nsmallest(df):
    for col in df[num].columns:
        print(col,"\n",df.nsmallest(10,col))
        print(" ")
        
def data_index_max(df):
    return df[num].idxmax()

def data_index_min(df):
    return df[num].idxmin()
        
def data_check_outliers(df):
    for col in df[num]:
        q = df[col].describe()
        IQR    = q['75%'] - q['25%']
        Upper  = q['75%'] + 1.5 * IQR
        Lower  = q['25%'] - 1.5 * IQR
        print("the upper and lower outliers are {} and {} of \n {}".format(Upper,Lower,col)) 
        
def data_check_outliers2(df):
    for col in df[num].columns:
        IQR = df[col].quantile(0.75) - df[col].quantile(0.25)
        Lower_fence = df[col].quantile(0.25) - (IQR * 1.5)
        Upper_fence = df[col].quantile(0.75) + (IQR * 1.5)

        print("Feature ",col, "\n" "Upper frence  \t  ",Upper_fence,"\t" "Lower frence      ",Lower_fence,"IQR    ",IQR)
        print(" \t ")
        
def data_check_outliers_extreme_values(df):
    for col in df[num].columns:
        IQR = df[col].quantile(0.75) - df[col].quantile(0.25)
        Lower_fence = df[col].quantile(0.25) - (IQR * 3)
        Upper_fence = df[col].quantile(0.75) + (IQR * 3)

        print("Feature ",col, "\n" "Upper frence  \t  ",Upper_fence,"\t" "Lower frence      ",Lower_fence,"\t" "IQR    ",IQR)
        print(" \t ")
        
def data_data_quants(df):
    for col in df[num].columns:
        quants = [0.05, 0.25, 0.5, 0.75, 0.95]
        mask = df[col].quantile(quants)
        return mask
        
def data_range(df):
    for col in df[num].columns:
        print(col,'---Range--- \n ',df[col].max()-df[col].min())
        print(" \n ")
        
def data_df_max(df):
    return df.max()

def data_df_min(df):
    return df.min()

def data_df_mean(df):
    return df.mean()

def data_df_medain(df):
    return df.median()

def data_df_std(df):
    return df.std()

def data_check_distribution_normality_values(df):
    for col in df[num]:
        upper_boundry = df[col].mean() + 3* df[col].std()
        lower_boundry = df[col].mean() - 3* df[col].std()
        print(col,"\n ",upper_boundry,lower_boundry)
        print(" ")
        
def data_sample(df):
    return df.sample(n = 20)

def check_Pearsons_corr(df):
    for col in df[num].columns:
        corr, _ = pearsonr(df[col],df[col])
        print(" ")
        print(col,'Pearsons correlation: %.3f' % corr)
        
def check_spearmanr_corr(df):
    for col in df[num].columns:
        corr, _ = spearmanr(df[col],df[col])
        print(" ")
        print(col,'spearmanr correlation: %.3f' % corr)
        
def check_Skewness(df):
    for col in df[num].columns:
        print(" ")
        print(col,"Skewness: %f" % df[col].skew())
        
def check_Kurtosis(df):
    for col in df[num].columns:
        print(" ")
        print(col,"Kurtosis: %f" % df[col].kurt())
        

for i in tqdm_notebook(range(10), desc = "Preprocessing Function"):
    time.sleep(0.1)
        

print("All Basic Preprocessing Function Imported")
print(" ")
# Out:
# HBox(children=(HTML(value='Preprocessing Function'), FloatProgress(value=0.0, max=10.0), HTML(value='')))
# All Basic Preprocessing Function Imported

# %%
def box_plots(df):
    for col in df[num]:
        plt.figure(figsize=(10,6))
        df.boxplot(column=col)
        plt.show()
        
def histplot_with_bins(df):
    for col in df[num].columns:
        plt.figure(figsize=(10,6))
        df[col].hist(bins = 50) 
        plt.xlabel(col)
        plt.ylabel('salary')
        plt.tight_layout()
        plt.show()
        
def histplot_with_bins2(df):
    for col in df[num].columns:
        plt.figure(figsize=(10,6))
        df[col].hist(bins = 100) 
        plt.xlabel(col)
        plt.ylabel('salary')
        plt.tight_layout()
        plt.show()
        
def histplot_with_bins3(df):
    for col in df[num].columns:
        plt.figure(figsize=(10,6))
        df[col].hist(bins = 50,density = True,cumulative = True) 
        plt.xlabel(col)
        plt.ylabel('salary')
        plt.tight_layout()
        plt.show()
        
def histplot_and_kdeplot(df):
    for col in df[num].columns:
        plt.figure(figsize=(15,6))
        plt.subplot(1,2,1)
        df[col].hist(bins = 50)
        plt.xlabel(col)
        plt.ylabel('salary')
        plt.tight_layout()
        
        plt.subplot(1,2,2)
        sns.kdeplot(df[col])
        plt.xlabel(col)
        plt.ylabel('salary')
        plt.tight_layout()
        plt.show()
        plt.show()
        
def histplot_and_QQplot(df):
    for col in df[num].columns:
        plt.figure(figsize=(15,6))
        plt.subplot(1,2,1)
        df[col].hist()
        plt.xlabel(col)
        plt.ylabel('salary')
        
        plt.subplot(1,2,2)
        stats.probplot(df[col],dist='norm',plot=pylab)
        plt.xlabel(col)
        plt.ylabel('salary')
        plt.tight_layout()
        plt.show()
        
def bar_and_line_plot(df):
    total_len = len(df)
    for col in df.drop('salary',axis=1):
        temp_df = pd.Series(df[col].value_counts()/total_len).reset_index()
        temp_df.columns = [col,col+'percenatge of salary']
        temp_df = temp_df.merge(df.groupby([col])['salary'].mean().reset_index(),on=col,how='left')
        
        fig,ax = plt.subplots()
        ax2 = ax.twinx()
        ax.bar(temp_df.index,temp_df[col+'percenatge of salary'],color = 'lightgrey',label = col)
        ax2.plot(temp_df.index,temp_df['salary'],color='green',)
        ax.set_xticklabels([0]+list(temp_df[col]))
        ax.set_xlabel(col)
        
def plot_feature(df,col):
    plt.figure(figsize=(16,7))
    plt.subplot(1,2,1)
    if df[col].dtype == 'int64':
        df[col].value_counts().sort_index().plot()
    else:
        mean = df.groupby(col)['salary'].mean()
        df[col] = df[col].astype('category')
        levels = mean.sort_values().index.tolist()
        df[col].cat.reorder_categories(levels,inplace=True)
        df[col].value_counts().plot()
    plt.xticks(rotation=45)
    plt.xlabel(col)
    plt.ylabel('Counts')
    plt.subplot(1,2,2)
    
    if df[col].dtype == 'int64' or col == 'salary':
        mean = df.groupby(col)['salary'].mean()
        std = df.groupby(col)['salary'].std()
        mean.plot()
        plt.fill_between(range(len(std.index)),mean.values-std.values,mean.values + std.values, \
                        alpha=0.1)
    else:
        sns.boxplot(x = col,y='salary',data=df)
    plt.xticks(rotation=45)
    plt.ylabel('salary')
    plt.show()  
    
for i in tqdm_notebook(range(10), desc = "EDA Function - 1"):
    time.sleep(0.1)
# Out:
# HBox(children=(HTML(value='EDA Function - 1'), FloatProgress(value=0.0, max=10.0), HTML(value='')))

# %%
def box_plots(df):
    for col in df[num]:
        plt.figure(figsize=(10,6))
        df.boxplot(column=col)
        plt.show()
        
def histplot_with_bins(df):
    for col in df[num].columns:
        plt.figure(figsize=(10,6))
        df[col].hist(bins = 50) 
        plt.xlabel(col)
        plt.ylabel('salary')
        plt.tight_layout()
        plt.show()
        
def histplot_with_bins2(df):
    for col in df[num].columns:
        plt.figure(figsize=(10,6))
        df[col].hist(bins = 100) 
        plt.xlabel(col)
        plt.ylabel('salary')
        plt.tight_layout()
        plt.show()
        
def histplot_with_bins3(df):
    for col in df[num].columns:
        plt.figure(figsize=(10,6))
        df[col].hist(bins = 50,density = True,cumulative = True) 
        plt.xlabel(col)
        plt.ylabel('salary')
        plt.tight_layout()
        plt.show()
        
def histplot_and_kdeplot(df):
    for col in df[num].columns:
        plt.figure(figsize=(15,6))
        plt.subplot(1,2,1)
        df[col].hist(bins = 50)
        plt.xlabel(col)
        plt.ylabel('salary')
        plt.tight_layout()
        
        plt.subplot(1,2,2)
        sns.kdeplot(df[col])
        plt.xlabel(col)
        plt.ylabel('salary')
        plt.tight_layout()
        plt.show()
        plt.show()
        
def histplot_and_QQplot(df):
    for col in df[num].columns:
        plt.figure(figsize=(15,6))
        plt.subplot(1,2,1)
        df[col].hist()
        plt.xlabel(col)
        plt.ylabel('salary')
        
        plt.subplot(1,2,2)
        stats.probplot(df[col],dist='norm',plot=pylab)
        plt.xlabel(col)
        plt.ylabel('salary')
        plt.tight_layout()
        plt.show()
        
def bar_and_line_plot(df):
    total_len = len(df)
    for col in df.drop('salary',axis=1):
        temp_df = pd.Series(df[col].value_counts()/total_len).reset_index()
        temp_df.columns = [col,col+'percenatge of salary']
        temp_df = temp_df.merge(df.groupby([col])['salary'].mean().reset_index(),on=col,how='left')
        
        fig,ax = plt.subplots()
        ax2 = ax.twinx()
        ax.bar(temp_df.index,temp_df[col+'percenatge of salary'],color = 'lightgrey',label = col)
        ax2.plot(temp_df.index,temp_df['salary'],color='green',)
        ax.set_xticklabels([0]+list(temp_df[col]))
        ax.set_xlabel(col)
        
def plot_feature(df,col):
    plt.figure(figsize=(16,7))
    plt.subplot(1,2,1)
    if df[col].dtype == 'int64':
        df[col].value_counts().sort_index().plot()
    else:
        mean = df.groupby(col)['salary'].mean()
        df[col] = df[col].astype('category')
        levels = mean.sort_values().index.tolist()
        df[col].cat.reorder_categories(levels,inplace=True)
        df[col].value_counts().plot()
    plt.xticks(rotation=45)
    plt.xlabel(col)
    plt.ylabel('Counts')
    plt.subplot(1,2,2)
    
    if df[col].dtype == 'int64' or col == 'salary':
        mean = df.groupby(col)['salary'].mean()
        std = df.groupby(col)['salary'].std()
        mean.plot()
        plt.fill_between(range(len(std.index)),mean.values-std.values,mean.values + std.values, \
                        alpha=0.1)
    else:
        sns.boxplot(x = col,y='salary',data=df)
    plt.xticks(rotation=45)
    plt.ylabel('salary')
    plt.show()  
    
for i in tqdm_notebook(range(10), desc = "EDA Function - 1"):
    time.sleep(0.1)
# Out:
# HBox(children=(HTML(value='EDA Function - 1'), FloatProgress(value=0.0, max=10.0), HTML(value='')))

# %%
# we will be using df2 for this Eda

# if u want to change background style use the below

# plt.style.use('fivethirtyeight')
# plt.style.use('ggplot')

#----------------------------------------------------Bar plot--------------------------------------
def numeric_bar(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.barplot(x=col,y=df2['response'],data=df2)
        plt.xlabel(col)
        plt.ylabel('response')
        plt.tight_layout()
        plt.show()
        
def numeric_bar_point(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.barplot(x=col,y=df2['response'],data=df2)
        sns.pointplot(x=col,y='response',data=df2,color='Black')
        plt.xlabel(col)
        plt.ylabel('response')
        plt.tight_layout()
        plt.show()

def cat_bar(df):
     for col in df2[cat].columns:
        plt.figure(figsize=(12,6))
        sns.barplot(x=col,y=df2['response'],data=df2)
        plt.xlabel(col)
        plt.ylabel('response')
        plt.tight_layout()
        plt.show()
        
def cat_bar_point(df):
    for col in df2[cat].columns:
        plt.figure(figsize=(12,6))
        sns.barplot(x=col,y=df2['response'],data=df2)
        sns.pointplot(x=col,y='response',data=df2,color='Black')
        plt.xlabel(col)
        plt.ylabel('response')
        plt.tight_layout()
        plt.show()
        
def numeric_bar_stripplot(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.barplot(x=col,y='response',data=df2)
        sns.stripplot(x=col,y='response',data=df2,jitter=True,color='Black')
        plt.tight_layout()
        plt.show()
        
def cat_bar_stripplot(df):
    for col in df2[cat].columns:
        plt.figure(figsize=(12,6))
        sns.barplot(x=col,y='response',data=df2)
        sns.stripplot(x=col,y='response',data=df2,jitter=True,color='Black')
        plt.tight_layout()
        plt.show()
        
#----------------------------------------------------Box plot-------------------------------------------
def numeric_box(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.boxplot(x=col,y=df2['response'],data=df2)
        plt.xlabel(col)
        plt.ylabel('response')
        plt.tight_layout()
        plt.show()
        
def cat_box(df):
     for col in df2[cat].columns:
        plt.figure(figsize=(12,6))
        sns.boxplot(x=col,y=df2['response'],data=df2)
        plt.xlabel(col)
        plt.ylabel('response')
        plt.tight_layout()
        plt.show()
        
def numeric_box_point(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.boxplot(x=col,y='response',data=df2)
        sns.pointplot(x=col,y='response',data=df2,color='Black')
        plt.tight_layout()
        plt.show()
        
def cat_box_point(df):
    for col in df2[cat].columns:
        plt.figure(figsize=(12,6))
        sns.boxplot(x=col,y='response',data=df2)
        sns.pointplot(x=col,y='response',data=df2,color='Black')
        plt.tight_layout()
        plt.show()
        
def numeric_box_stripplot(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.boxplot(x=col,y='response',data=df2)
        sns.stripplot(x=col,y='response',data=df2,jitter=True,edgecolor='gray')
        plt.tight_layout()
        plt.show()
        
def cat_box_stripplot(df):
    for col in df2[cat].columns:
        plt.figure(figsize=(12,6))
        sns.boxplot(x=col,y='response',data=df2)
        sns.stripplot(x=col,y='response',data=df2,jitter=True,edgecolor='gray')
        plt.tight_layout()
        plt.show()
        
#----------------------------------------------------Boxen plot------------------------------------           
def numeric_boxen_plot(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.boxenplot(x=col,y=df2['response'],data=df2)
        plt.xlabel(col)
        plt.ylabel('response')
        plt.tight_layout()
        plt.show() 
        
def cat_boxen_plot(df):
    for col in df2[cat].columns:
        plt.figure(figsize=(12,6))
        sns.boxenplot(x=col,y=df2['response'],data=df2)
        plt.xlabel(col)
        plt.ylabel('response')
        plt.tight_layout()
        plt.show()
        
def numeric_boxen_point_plot(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.boxenplot(x=col,y=df2['response'],data=df2)
        sns.pointplot(x=col,y='response',data=df2,color='Black')
        plt.xlabel(col)
        plt.ylabel('response')
        plt.tight_layout()
        plt.show() 
        
def cat_boxen_point_plot(df):
    for col in df2[cat].columns:
        plt.figure(figsize=(12,6))
        sns.boxenplot(x=col,y=df2['response'],data=df2)
        sns.pointplot(x=col,y='response',data=df2,color='Black')
        plt.xlabel(col)
        plt.ylabel('response')
        plt.tight_layout()
        plt.show() 
        
def numeric_boxen_stripplot(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.boxenplot(x=col,y='response',data=df2)
        sns.stripplot(x=col,y='response',data=df2,jitter=True,edgecolor='gray')
        plt.tight_layout()
        plt.show()
        
def cat_boxen_stripplot(df):
    for col in df2[cat].columns:
        plt.figure(figsize=(12,6))
        sns.boxenplot(x=col,y='response',data=df2)
        sns.stripplot(x=col,y='response',data=df2,jitter=True,edgecolor='gray')
        plt.tight_layout()
        plt.show()
        
#-------------------------------------------------------VIOLIN Plot-----------------------------------         
def numeric_violinplot(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.violinplot(x=col,y=df2['response'],data=df2)
        plt.xlabel(col)
        plt.ylabel('response')
        plt.tight_layout()
        plt.show()
        
def cat_violinplot(df):
    for col in df2[cat].columns:
        plt.figure(figsize=(12,6))
        sns.violinplot(x=col,y=df2['response'],data=df2)
        plt.xlabel(col)
        plt.ylabel('response')
        plt.tight_layout()
        plt.show()
        
def numeric_violinplot_stripplot(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.violinplot(x=col,y=df2['response'],data=df2)
        sns.stripplot(x=col,y=df2['response'],data=df2,jitter=True,edgecolor='gray')
        plt.xlabel(col)
        plt.ylabel('response')
        plt.tight_layout()
        plt.show()
        
def cat_violinplot_stripplot(df):
    for col in df2[cat].columns:
        plt.figure(figsize=(12,6))
        sns.violinplot(x=col,y=df2['response'],data=df2)
        sns.stripplot(x=col,y=df2['response'],data=df2,jitter=True,edgecolor='gray')
        plt.xlabel(col)
        plt.ylabel('Survived')
        plt.tight_layout()
        plt.show()
        
#-------------------------------------------------------Joint Plot----------------------------------
def numeric_joint(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.jointplot(x=col,y=df2['response'],data=df2)
        plt.xlabel(col)
        plt.ylabel('response')
        plt.tight_layout()
        plt.show()
        
def numeric_joint_reg(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.jointplot(x=col,y='response',data=df2,kind='reg')
        plt.xlabel(col)
        plt.ylabel('response')
        plt.tight_layout()
        plt.show()
        
def numeric_joint_hex(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.jointplot(x=col,y=df2['response'],data=df2,kind='hex',color='g')
        plt.xlabel(col)
        plt.ylabel('response')
        plt.tight_layout()
        plt.show()
        
def numeric_joint_hex2(df):
    for col in df[num].columns:
        plt.figure(figsize=(12,6))
        sns.jointplot(x=col,y='response',data=df,kind='hex')
        plt.xlabel(col)
        plt.ylabel('response')
        plt.tight_layout()
        plt.show()
        
def numeric_joint_reg(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.jointplot(x=col,y='response',data=df2,kind='reg')
        plt.xlabel(col)
        plt.ylabel('response')
        plt.tight_layout()
        plt.show()
        
def numeric_joint_kde(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.jointplot(x=col,y='response',data=df2,color='r',kind='kde')
        plt.xlabel(col)
        plt.ylabel('response')
        plt.tight_layout()
        plt.show()
        
def numeric_joint_kde2(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.jointplot(x=col,y='response',data=df2,color='magenta',kind='kde')
        plt.xlabel(col)
        plt.ylabel('response')
        plt.tight_layout()
        plt.show()
        
#----------------------------------------------------Lm Plot-------------------------------------- 
def numeric_lm_plot(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.lmplot(x=col,y='response',data=df2,aspect=1,height=8,col = None)
        plt.xlabel(col)
        plt.ylabel('response')
        plt.tight_layout()
        plt.show()

#----------------------------------------------------KDE Plot--------------------------------------
def numeric_kde(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.kdeplot(data=df2[col])
        plt.xlabel(col)
        plt.ylabel('response')
        plt.tight_layout()
        plt.show()
        
#------------------------------------------------------Numeric Relationship------------------------       
def numeric_linear_Relation(df):
    rows = 3
    cols = 2
    fig,ax = plt.subplots(nrows=rows,ncols=cols,figsize=(16,11))
    col = df2[num].columns
    index = 0
    for i in range(rows):
        for j in range(cols):
            sns.regplot(x=df2[col[index]],y=df2['response'],ax=ax[i][j])
        index = index + 1
        
#----------------------------------------------------Cat Plot-------------------------------------
def numeric_and_cat_catplot(df):
    for col in df2.columns:
        plt.figure(figsize=(18,9))
        sns.catplot(data=df2,x=col,y='response')
        plt.xlabel(col)
        plt.ylabel('response')
        plt.tight_layout()
        plt.show()
        
def numeric_and_cat_catplot_pointplot(df):
    for col in df2.columns:
        plt.figure(figsize=(18,9))
        sns.catplot(data=df2,x=col,y='response')
        sns.pointplot(x = col,y ='response',data=df2,color='Black')
        plt.xlabel(col)
        plt.ylabel('response')
        plt.tight_layout()
        plt.show()

#-------------------------------------------------------Stripplot Plot---------------------------    
def numeric_stripplot(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.stripplot(x=col,y=df2['response'],data=df2,jitter=True,edgecolor='gray',size=10,palette='winter',orient='v')
        plt.xlabel(col)
        plt.ylabel('response')
        plt.tight_layout()
        plt.show()
        
#-------------------------------------------------------swarmplot Plot---------------------------   
def numeric_swarmplot(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.swarmplot(x=col,y='response',data=df2)
        plt.xlabel(col)
        plt.ylabel("response")
        plt.tight_layout()
        plt.show()
        
def cat_swarmplot(df):
    for col in df2[cat].columns:
        plt.figure(figsize=(12,6))
        sns.swarmplot(x=col,y='response',data=df2)
        plt.xlabel(col)
        plt.ylabel('response')
        plt.tight_layout()
        plt.show()
        
#----------------------------------------------------Scatter-Plot-----------------------------------
def numeric_scatter(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        plt.scatter(x=col,y='response',data=df2)
        plt.tight_layout()
        plt.xlabel(col)
        plt.ylabel('response')
        plt.show() 
        
def numeric_scatter2(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        plt.scatter(x=col,y='response',data=df2)
        plt.tight_layout()
        plt.xlabel(col)
        plt.ylabel('response')
        plt.axhline(15,color='Black')
        plt.show()   
        
def numeric_scatter3(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        plt.scatter(x=col,y='response',data=df2)
        plt.tight_layout()
        plt.xlabel(col)
        plt.ylabel('response')
        plt.axhline(15,color='Black')
        plt.axvline(50,color='Black')
        plt.show()        
              
#-------------------------------------------------------factor Plot-----------------------------------     
def numeric_factorplot(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.factorplot(x=col,y='response',data=df2)
        plt.xlabel(col)
        plt.ylabel('response')
        plt.tight_layout()
        plt.show()
        
#-------------------------------------------------------Resid Plot--------------------------------------    
def numeric_residplot(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.residplot(x=col,y='response',data=df2)
        plt.xlabel(col)
        plt.ylabel('response')
        plt.tight_layout()
        plt.show()
        
#-------------------------------------------------------Dis Plot-----------------------------------------      
def numeric_dis(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.distplot(df2[col],color='red')
        plt.xlabel(col)
        plt.ylabel('response')
        plt.tight_layout()
        plt.show()
        
def numeric_dis2(df):
    rows = 2
    cols = 2
    fig,ax = plt.subplots(nrows=rows,ncols=cols,figsize=(16,10))
    col = df2[num].columns
    index = 0
    for i in range(rows):
        for j in range(cols):
            sns.distplot(df2[col[index]],ax=ax[i][j])
            index = index + 1
    plt.tight_layout()
    plt.show()
        
#------------------------------------------------------Pandas  Plot-------------------------------------
def numeric_pandas_plot(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        plt.plot(col,'response',data=df2)
        plt.xlabel(col)
        plt.ylabel('response')
        plt.tight_layout()
        plt.show()
        
#------------------------------------------------------Pandas bar Plot-----------------------------------
def numeric_pandas_bar(df):
    for col in df2[num].columns:
        plt.figure(figsize=(15,6))
        plt.bar(col,'response',data=df2)
        plt.xlabel(col)
        plt.ylabel("response")
        plt.tight_layout()
        plt.show()
        
def cat_pandas_bar(df):
     for col in df2[cat].columns:
        plt.figure(figsize=(15,6))
        plt.bar(col,'response',data=df2)
        plt.xlabel(col)
        plt.ylabel('response')
        plt.tight_layout()
        plt.show()
        
#------------------------------------------------------Line Plot------------------------------------------
def numeric_lineplot(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.lineplot(x=col,y='response',data=df2)
        plt.xlabel(col)
        plt.ylabel('response')
        plt.tight_layout()
        plt.show()
        
#------------------------------------------------------Scipy Plot------------------------------------------    
def numeric_scipy_prob(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        st.probplot(df2[col],plot=plt)
        plt.xlabel(col)
        plt.ylabel('response')
        plt.tight_layout()
        plt.show()
        
#-----------------------------------------------------Numeric Value Counts Plot------------------------------
def numeric_value_counts(df):
    for col in df2[num]:
        plt.figure(figsize=(12,6))
        plt.plot(df2[col].value_counts())
        plt.xlabel(col)
        plt.ylabel('response')
        plt.tight_layout()
        plt.show()
        
#------------------------------------------------------Pie and bar plot--------------------------------------   
def numeric_pie_and_bar(df):
    for col in df2[num].columns:
        fig,ax=plt.subplots(1,2,figsize=(18,8))
        df2[col].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
        ax[0].set_title(col)
        ax[0].set_ylabel(col)
        sns.countplot(col,data=df2,ax=ax[1],order=df2[col].value_counts().index)
        ax[1].set_title(col)
        plt.show()
        
def cat_pie_and_bar(df):
    for col in df2[cat].columns:
        fig,ax=plt.subplots(1,2,figsize=(18,8))
        df2[col].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
        ax[0].set_title(col)
        ax[0].set_ylabel(col)
        sns.countplot(col,data=df2,ax=ax[1],order=df2[col].value_counts().index)
        ax[1].set_title(col)
        plt.show()
        
#------------------------------------------------------barh and pie plot------------------------------------
def numeric_barh_and_pie(df):
    for col in df2[num].columns:
        fig,ax=plt.subplots(1,2,figsize=(15,8))
        clr = ("blue", "forestgreen", "gold", "red", "purple",'cadetblue','hotpink','orange','darksalmon','brown')
        df3[col].value_counts().sort_values(ascending=False).sort_values().plot(kind='barh',color=clr,ax=ax[0])
        ax[0].set_title("wheelbase",size=20)
        ax[0].set_xlabel('wheelbase',size=18)
        count=df3[col].value_counts()
        groups=list(df3[col].value_counts().index)
        counts=list(count)
        counts.append(count.agg(sum)-count.agg('sum'))
        groups.append('Other')
        type_dict=pd.DataFrame({"group":groups,"counts":counts})
        clr1=('brown','darksalmon','orange','hotpink','cadetblue','purple','red','gold','forestgreen','blue','plum')
        qx=type_dict.plot(kind='pie',y='counts',labels=groups,colors=clr1,autopct='%1.1f%%',pctdistance=0.9,radius=1.2,ax=ax[1])
        plt.legend(loc=0, bbox_to_anchor=(1.15,0.4)) 
        plt.subplots_adjust(wspace =0.5, hspace =0)
        plt.ioff()
        plt.ylabel('')
        plt.show()
        
def cat_barh_and_pie(df):
    for col in df2[cat].columns:
        fig,ax=plt.subplots(1,2,figsize=(15,8))
        clr = ("blue", "forestgreen", "gold", "red", "purple",'cadetblue','hotpink','orange','darksalmon','brown')
        df2[col].value_counts().sort_values(ascending=False).sort_values().plot(kind='barh',color=clr,ax=ax[0])
        ax[0].set_title("wheelbase",size=20)
        ax[0].set_xlabel('wheelbase',size=18)
        count=df2[col].value_counts()
        groups=list(df2[col].value_counts().index)
        counts=list(count)
        counts.append(count.agg(sum)-count.agg('sum'))
        groups.append('Other')
        type_dict=pd.DataFrame({"group":groups,"counts":counts})
        clr1=('brown','darksalmon','orange','hotpink','cadetblue','purple','red','gold','forestgreen','blue','plum')
        qx=type_dict.plot(kind='pie',y='counts',labels=groups,colors=clr1,autopct='%1.1f%%',pctdistance=0.9,radius=1.2,ax=ax[1])
        plt.legend(loc=0, bbox_to_anchor=(1.15,0.4)) 
        plt.subplots_adjust(wspace =0.5, hspace =0)
        plt.ioff()
        plt.ylabel('')
        plt.show()
        
#------------------------------------------------------dis and scatter sub plot---------------------------   
def numeric_sub_plot(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,5))
        plt.subplot(1,2,1)
        g = sns.distplot((df2[col] + 1))
        plt.subplot(1,2,2)
        plt.scatter(range(df2.shape[0]), np.sort(np.log(df2[col]+1).values))
        plt.xticks(rotation=45)
        plt.show() 
        
def numeric_sub_plot2(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,5))
        plt.subplot(1,2,1)
        g = sns.distplot(df2[col].values, bins=100, kde=False)
        plt.subplot(1,2,2)
        plt.scatter(range(df2.shape[0]), np.sort(np.log(df2[col]+1).values))
        plt.xticks(rotation=45)
        plt.show() 
        
#------------------------------------------------------hist sub plot-----------------------------------------      
def numeric_two_hist(df):
    for col in df2[num].columns:
        fig,axes=plt.subplots(nrows=2,ncols=1)
        df2.plot(kind='hist',y=col,bins=50,range=(0,100),density=True,ax=axes[0])
        df2.plot(kind='hist',y=col,bins=100,density=True,ax=axes[1],cumulative=True)
        plt.show()  
        
#----------------------------------------------------Dis and Kde sub plot--------------------------------------   
def numeric_displot_and_kde(df):
    plt.figure(figsize=(20,25))
    i = 0
    for item in df2[num].columns:
        i += 1
        plt.subplot(8, 2, i)
        sns.distplot(df2[item], rug=True, rug_kws={"color": "b"},kde=True,
                 kde_kws={"color": "blue", "lw": 5, "label": "KDE"},
                 hist_kws={"histtype": "step", "linewidth": 3,"alpha": 1, "color": "blue"},label="{0}".format(item))
plt.show()

#----------------------------------------------------Dis and Kde sub plot---------------------------------------    
def numeric_dis_and_prob_plot(df):
    for col in df2[num].columns:
        sns.distplot(df2[col], fit=norm);
        fig = plt.figure()
        res = stats.probplot(df2[col], plot=plt) 
        fig = plt.figure()
        
#----------------------------------------------------target sub plot----------------------------------------------
def target_subplot(df):
    plt.figure(figsize=(14,6))
    plt.subplot(1,2,1)
    sns.boxplot(df2.Sales)
    plt.subplot(1,2,2)
    sns.distplot(df2.Sales,bins=20)
    plt.show()
    
#----------------------------------------------------Numeric sub and reg plot--------------------------------------         
def numeric_sub_plot_reg_and_target(df):
    rows = 2
    cols = 2
    fig,ax = plt.subplots(nrows=rows,ncols=cols,figsize=(16,35))
    col = df2[num].columns
    index = 0
    for i in range(rows):
        for j in range(cols):
            sns.regplot(x=df2[col[index]],y=df2['response'],ax=ax[i][j])
            index = index + 1    
plt.show()

#----------------------------------------------------Learning Curve plot--------------------------------------------
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Validation score")

    plt.legend(loc="best")
    return plt

# %%
def show_All_scores(model):
    train = model.predict(X_train)
    test  = model.predict(X_test)
   
    print("\n Training f1_score \n",f1_score(y_train, train))
    print("\n \t Testing f1_score \n",f1_score(y_test, test))
    
    print("\n Training precision_score \n",precision_score(y_train, train))
    print("\n \t Testing precision_score \n", precision_score(y_test, test))
    
    print("\n Training recall_score \n", recall_score(y_train, train))
    print("\n \t Testing recall_score \n", recall_score(y_test, test))
    
    print("\n Training accuracy_score \n", accuracy_score(y_train, train))
    print("\n \t Testing accuracy_score \n", accuracy_score(y_test, test)) 
    
    print("\n Training roc_auc_score \n", roc_auc_score(y_train, train))
    print("\n \t Testing roc_auc_score \n", roc_auc_score(y_test, test)) 
    
def evaluate_metric(y_test,pred):
    accuracy  = accuracy_score(y_test,pred)
    f1        = f1_score(y_test,pred)
    recall    = recall_score(y_test,pred)
    precision = precision_score(y_test,pred)
    
    metric_dict = {"accuracy":round(accuracy,2),
                  "Precision":round(precision,2),
                  "recall":round(recall,2),
                  "F1":round(f1,2)}
    
    print(f"accuracy:{accuracy * 100:.2f}%")
    print(f"Precision:{precision:.2f}")
    print(f"Recall:{recall:.2f}")
    print(f"f1_score:{f1:.2f}")
    return metric_dict

# %%
def print_summary(model,show_All_scores):
    print('\n \t Model:\n',model)
    show_All_scores(model)

# %%
df = pd.read_json('data.json')

# %%
df
# Out:
#                                                    req  isSafe
# 0    {'baseUrl': '/crm/note', 'body': {'note': {'ti...    True
# 1    {'baseUrl': '/crm/note', 'body': {'note': {'ti...    True
# 2    {'baseUrl': '/crm/note', 'body': {'note': {'ti...   False
# 3    {'baseUrl': '/crm/note', 'body': {'note': {'ti...    True
# 4    {'baseUrl': '/crm/note', 'body': {'note': {'ti...   False
# ..                                                 ...     ...
# 995  {'baseUrl': '/crm/note', 'body': {'note': {'ti...    True
# 996  {'baseUrl': '/crm/note', 'body': {'note': {'ti...   False
# 997  {'baseUrl': '/crm/note', 'body': {'note': {'ti...    True
# 998  {'baseUrl': '/crm/note', 'body': {'note': {'ti...    True
# 999  {'baseUrl': '/crm/note', 'body': {'note': {'ti...    True
#
# [1000 rows x 2 columns]

# %%
fig, ax = plt.subplots()
g = sns.countplot(df['isSafe'], palette='viridis')
#g.set_xticklabels(['False', 'True'])
g.set_yticklabels([])

# function to show values on bars
def show_values_on_bars(axs):
    def _show_on_single_plot(ax):        
        for p in ax.patches:
            _x = p.get_x() + p.get_width() / 2
            _y = p.get_y() + p.get_height()
            value = '{:.0f}'.format(p.get_height())
            ax.text(_x, _y, value, ha="center") 

    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _show_on_single_plot(ax)
    else:
        _show_on_single_plot(axs)
show_values_on_bars(ax)

sns.despine(left=True, bottom=True)
plt.xlabel('')
plt.ylabel('')
plt.title('Urls Target', fontsize=30)
plt.tick_params(axis='x', which='major', labelsize=15)
plt.show()

# %%
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer()

# %%
def preprocess(sentence):
    sentence=str(sentence)
    sentence = sentence.lower()
    sentence=sentence.replace('{html}',"") 
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, '', sentence)
    rem_url=re.sub(r'http\S+', '',cleantext)
    rem_num = re.sub('[0-9]+', '', rem_url)
    tokenizer = RegexpTokenizer(r'\w+')
    tokens = tokenizer.tokenize(rem_num)  
    filtered_words = [w for w in tokens if len(w) > 2 if not w in stopwords.words('english')]
    stem_words=[stemmer.stem(w) for w in filtered_words]
    lemma_words=[lemmatizer.lemmatize(w) for w in stem_words]
    return " ".join(filtered_words)

# %%
# %%time
df['req'] = df['req'].apply(lambda x:preprocess(x))
# Out:
# Wall time: 20.5 s

# %%
df
# Out:
#                                                    req  isSafe
# 0    baseurl crm note body note title tina johnson ...    True
# 1    baseurl crm note body note title clayton coope...    True
# 2    baseurl crm note body note title curtis wolfe ...   False
# 3    baseurl crm note body note title laura fisher ...    True
# 4    baseurl crm note body note title tyler santos ...   False
# ..                                                 ...     ...
# 995  baseurl crm note body note title bridget ellio...    True
# 996  baseurl crm note body note title james rocha d...   False
# 997  baseurl crm note body note title jasmine gibso...    True
# 998  baseurl crm note body note title antonio valde...    True
# 999  baseurl crm note body note title brian stephen...    True
#
# [1000 rows x 2 columns]

# %%
tfid = TfidfVectorizer() 
data = tfid.fit_transform(df['req']).toarray()

# %%
X = data
y = df['isSafe']

# %%
np.random.seed(42)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=100)

print('\n Split_data_shapes')
print('\nX_train:\n',  X_train.shape)
print('\ny_train:\n',  y_train.shape)
print('\nX_test:\n',   X_train.shape)
print('\ny_test:\n',   X_test.shape)
# Out:
#  Split_data_shapes
#
# X_train:
#  (700, 2137)
#
# y_train:
#  (700,)
#
# X_test:
#  (700, 2137)
#
# y_test:
#  (300, 2137)

# %%
log = LogisticRegression()
np.random.seed(42)
log.fit(X_train,y_train)
pred = log.predict(X_test)
show_All_scores(log)
# Out:
#  Training f1_score
#  0.88
#
#  	 Testing f1_score
#  0.8771929824561403
#
#  Training precision_score
#  0.7872763419483101
#
#  	 Testing precision_score
#  0.78125
#
#  Training recall_score
#  0.9974811083123426
#
#  	 Testing recall_score
#  1.0
#
#  Training accuracy_score
#  0.8457142857142858
#
#  	 Testing accuracy_score
#  0.8366666666666667
#
#  Training roc_auc_score
#  0.8221728973904948
#
#  	 Testing roc_auc_score
#  0.804

# %%
evaluate_metric(y_test,pred)
# Out:
# accuracy:83.67%
# Precision:0.78
# Recall:1.00
# f1_score:0.88
# {'accuracy': 0.84, 'Precision': 0.78, 'recall': 1.0, 'F1': 0.88}

# %%
rf = RandomForestClassifier()
np.random.seed(42)
rf.fit(X_train,y_train)
pred = rf.predict(X_test)
show_All_scores(rf)
# Out:
#  Training f1_score
#  1.0
#
#  	 Testing f1_score
#  0.8708860759493671
#
#  Training precision_score
#  1.0
#
#  	 Testing precision_score
#  0.7818181818181819
#
#  Training recall_score
#  1.0
#
#  	 Testing recall_score
#  0.9828571428571429
#
#  Training accuracy_score
#  1.0
#
#  	 Testing accuracy_score
#  0.83
#
#  Training roc_auc_score
#  1.0
#
#  	 Testing roc_auc_score
#  0.7994285714285715

# %%
evaluate_metric(y_test,pred)
# Out:
# accuracy:83.00%
# Precision:0.78
# Recall:0.98
# f1_score:0.87
# {'accuracy': 0.83, 'Precision': 0.78, 'recall': 0.98, 'F1': 0.87}

# %%
log = LogisticRegression()

np.random.seed(42)

log.fit(X_train,y_train)
pred = log.predict(X_test)

print("accuracy score",(accuracy_score(y_test,pred)))
print(" ")
print("F1 Score",(f1_score(y_test,pred)))
print(" ")
print("Recall Score",(recall_score(y_test,pred)))
print(" ")
print("Precision Score",(precision_score(y_test,pred)))
print(" ")
print("Classfication Report \n ",(classification_report(y_test,pred)))
print(" ")
print("Confusion Matrix \n ",(confusion_matrix(y_test,pred)))
# Out:
# accuracy score 0.8366666666666667
#
# F1 Score 0.8771929824561403
#
# Recall Score 1.0
#
# Precision Score 0.78125
#
# Classfication Report
#                 precision    recall  f1-score   support
#
#        False       1.00      0.61      0.76       125
#         True       0.78      1.00      0.88       175
#
#     accuracy                           0.84       300
#    macro avg       0.89      0.80      0.82       300
# weighted avg       0.87      0.84      0.83       300
#
#
# Confusion Matrix
#   [[ 76  49]
#  [  0 175]]

# %%
rf = RandomForestClassifier()

np.random.seed(42)

rf.fit(X_train,y_train)
pred = rf.predict(X_test)

print("accuracy score",(accuracy_score(y_test,pred)))
print(" ")
print("F1 Score",(f1_score(y_test,pred)))
print(" ")
print("Recall Score",(recall_score(y_test,pred)))
print(" ")
print("Precision Score",(precision_score(y_test,pred)))
print(" ")
print("Classfication Report \n ",(classification_report(y_test,pred)))
print(" ")
print("Confusion Matrix \n ",(confusion_matrix(y_test,pred)))
# Out:
# accuracy score 0.83
#
# F1 Score 0.8708860759493671
#
# Recall Score 0.9828571428571429
#
# Precision Score 0.7818181818181819
#
# Classfication Report
#                 precision    recall  f1-score   support
#
#        False       0.96      0.62      0.75       125
#         True       0.78      0.98      0.87       175
#
#     accuracy                           0.83       300
#    macro avg       0.87      0.80      0.81       300
# weighted avg       0.86      0.83      0.82       300
#
#
# Confusion Matrix
#   [[ 77  48]
#  [  3 172]]

# %%
dtree = DecisionTreeClassifier()

np.random.seed(42)

dtree.fit(X_train,y_train)
pred = dtree.predict(X_test)

print("accuracy score",(accuracy_score(y_test,pred)))
print(" ")
print("F1 Score",(f1_score(y_test,pred)))
print(" ")
print("Recall Score",(recall_score(y_test,pred)))
print(" ")
print("Precision Score",(precision_score(y_test,pred)))
print(" ")
print("Classfication Report \n ",(classification_report(y_test,pred)))
print(" ")
print("Confusion Matrix \n ",(confusion_matrix(y_test,pred)))
# Out:
# accuracy score 0.76
#
# F1 Score 0.7882352941176471
#
# Recall Score 0.7657142857142857
#
# Precision Score 0.8121212121212121
#
# Classfication Report
#                 precision    recall  f1-score   support
#
#        False       0.70      0.75      0.72       125
#         True       0.81      0.77      0.79       175
#
#     accuracy                           0.76       300
#    macro avg       0.75      0.76      0.76       300
# weighted avg       0.76      0.76      0.76       300
#
#
# Confusion Matrix
#   [[ 94  31]
#  [ 41 134]]

# %%
gb = GradientBoostingClassifier()

np.random.seed(42)

gb.fit(X_train,y_train)
pred = gb.predict(X_test)

print("accuracy score",(accuracy_score(y_test,pred)))
print(" ")
print("F1 Score",(f1_score(y_test,pred)))
print(" ")
print("Recall Score",(recall_score(y_test,pred)))
print(" ")
print("Precision Score",(precision_score(y_test,pred)))
print(" ")
print("Classfication Report \n ",(classification_report(y_test,pred)))
print(" ")
print("Confusion Matrix \n ",(confusion_matrix(y_test,pred)))
# Out:
# accuracy score 0.8
#
# F1 Score 0.8429319371727749
#
# Recall Score 0.92
#
# Precision Score 0.7777777777777778
#
# Classfication Report
#                 precision    recall  f1-score   support
#
#        False       0.85      0.63      0.72       125
#         True       0.78      0.92      0.84       175
#
#     accuracy                           0.80       300
#    macro avg       0.81      0.78      0.78       300
# weighted avg       0.81      0.80      0.79       300
#
#
# Confusion Matrix
#   [[ 79  46]
#  [ 14 161]]

# %%
svm = SVC()

np.random.seed(42)

svm.fit(X_train,y_train)
pred = svm.predict(X_test)

print("accuracy score",(accuracy_score(y_test,pred)))
print(" ")
print("F1 Score",(f1_score(y_test,pred)))
print(" ")
print("Recall Score",(recall_score(y_test,pred)))
print(" ")
print("Precision Score",(precision_score(y_test,pred)))
print(" ")
print("Classfication Report \n ",(classification_report(y_test,pred)))
print(" ")
print("Confusion Matrix \n ",(confusion_matrix(y_test,pred)))
# Out:
# accuracy score 0.8366666666666667
#
# F1 Score 0.8771929824561403
#
# Recall Score 1.0
#
# Precision Score 0.78125
#
# Classfication Report
#                 precision    recall  f1-score   support
#
#        False       1.00      0.61      0.76       125
#         True       0.78      1.00      0.88       175
#
#     accuracy                           0.84       300
#    macro avg       0.89      0.80      0.82       300
# weighted avg       0.87      0.84      0.83       300
#
#
# Confusion Matrix
#   [[ 76  49]
#  [  0 175]]

# %%
knn = KNeighborsClassifier()

np.random.seed(42)

knn.fit(X_train,y_train)
pred = knn.predict(X_test)

print("accuracy score",(accuracy_score(y_test,pred)))
print(" ")
print("F1 Score",(f1_score(y_test,pred)))
print(" ")
print("Recall Score",(recall_score(y_test,pred)))
print(" ")
print("Precision Score",(precision_score(y_test,pred)))
print(" ")
print("Classfication Report \n ",(classification_report(y_test,pred)))
print(" ")
print("Confusion Matrix \n ",(confusion_matrix(y_test,pred)))
# Out:
# accuracy score 0.4166666666666667
#
# F1 Score 0.0
#
# Recall Score 0.0
#
# Precision Score 0.0
#
# Classfication Report
#                 precision    recall  f1-score   support
#
#        False       0.42      1.00      0.59       125
#         True       0.00      0.00      0.00       175
#
#     accuracy                           0.42       300
#    macro avg       0.21      0.50      0.29       300
# weighted avg       0.17      0.42      0.25       300
#
#
# Confusion Matrix
#   [[125   0]
#  [175   0]]

# %%
xg = XGBClassifier()

np.random.seed(42)

xg.fit(X_train,y_train)
pred = xg.predict(X_test)

print("accuracy score",(accuracy_score(y_test,pred)))
print(" ")
print("F1 Score",(f1_score(y_test,pred)))
print(" ")
print("Recall Score",(recall_score(y_test,pred)))
print(" ")
print("Precision Score",(precision_score(y_test,pred)))
print(" ")
print("Classfication Report \n ",(classification_report(y_test,pred)))
print(" ")
print("Confusion Matrix \n ",(confusion_matrix(y_test,pred)))
# Out:
# [23:13:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# accuracy score 0.7766666666666666
#
# F1 Score 0.8203753351206434
#
# Recall Score 0.8742857142857143
#
# Precision Score 0.7727272727272727
#
# Classfication Report
#                 precision    recall  f1-score   support
#
#        False       0.78      0.64      0.70       125
#         True       0.77      0.87      0.82       175
#
#     accuracy                           0.78       300
#    macro avg       0.78      0.76      0.76       300
# weighted avg       0.78      0.78      0.77       300
#
#
# Confusion Matrix
#   [[ 80  45]
#  [ 22 153]]

# %%
rf = RandomForestClassifier()

parameters = {'max_features': ['log2', 'sqrt','auto'], 
              'criterion': ['gini', 'entropy'],
              'max_depth': [2, 3, 5, 10, 15], 
              'min_samples_split': [2, 3, 4],
              'min_samples_leaf': [1, 2, 3],
              'n_estimators' : [10, 20, 30, 50, 80, 100],
              'bootstrap': [True, False]
              }

rand_search = RandomizedSearchCV(rf, 
                           parameters,
                           scoring='accuracy',
                          cv = 5,
                          n_jobs=-1,
                          verbose = 1)
np.random.seed(42)

rand_search.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    5.4s finished
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'criterion': ['gini', 'entropy'],
#                                         'max_depth': [2, 3, 5, 10, 15],
#                                         'max_features': ['log2', 'sqrt',
#                                                          'auto'],
#                                         'min_samples_leaf': [1, 2, 3],
#                                         'min_samples_split': [2, 3, 4],
#                                         'n_estimators': [10, 20, 30, 50, 80,
#                                                          100]},
#                    scoring='accuracy', verbose=1)

# %%
rand_search.best_score_
# Out:
# 0.8242857142857142

# %%
rand_search.best_params_
# Out:
# {'n_estimators': 30,
#  'min_samples_split': 4,
#  'min_samples_leaf': 3,
#  'max_features': 'auto',
#  'max_depth': 3,
#  'criterion': 'entropy',
#  'bootstrap': True}

# %%
rand_search.best_estimator_
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=3, min_samples_leaf=3,
#                        min_samples_split=4, n_estimators=30)

# %%
rf_rand =  RandomForestClassifier(criterion='entropy', max_depth=2, max_features='log2',
                       min_samples_leaf=3, min_samples_split=4,
                       n_estimators=30)

np.random.seed(42)
rf_rand.fit(X_train,y_train)
pred = rf_rand.predict(X_test)

print("Precision Score",precision_score(y_test,pred))
print("Recall Score",recall_score(y_test,pred))
print("F1 Score",f1_score(y_test,pred))
print("Accuracy Score",accuracy_score(y_test,pred))
print("Roc_Auc Score",roc_auc_score(y_test,pred))
print(" ")
print(classification_report(y_test,pred))
print(" ")
print(confusion_matrix(y_test,pred))
print(" ")
print(evaluate_metric(y_test,pred))
# Out:
# Precision Score 0.78125
# Recall Score 1.0
# F1 Score 0.8771929824561403
# Accuracy Score 0.8366666666666667
# Roc_Auc Score 0.804
#
#               precision    recall  f1-score   support
#
#        False       1.00      0.61      0.76       125
#         True       0.78      1.00      0.88       175
#
#     accuracy                           0.84       300
#    macro avg       0.89      0.80      0.82       300
# weighted avg       0.87      0.84      0.83       300
#
#
# [[ 76  49]
#  [  0 175]]
#
# accuracy:83.67%
# Precision:0.78
# Recall:1.00
# f1_score:0.88
# {'accuracy': 0.84, 'Precision': 0.78, 'recall': 1.0, 'F1': 0.88}

# %%
svm = SVC(C = 10,kernel='rbf',gamma=0.1)
np.random.seed(42)
svm.fit(X_train,y_train)
pred = svm.predict(X_test)

print("Precision Score",precision_score(y_test,pred))
print("Recall Score",recall_score(y_test,pred))
print("F1 Score",f1_score(y_test,pred))
print("Accuracy Score",accuracy_score(y_test,pred))
print("Roc_Auc Score",roc_auc_score(y_test,pred))
print(" ")
print(classification_report(y_test,pred))
print(" ")
print(confusion_matrix(y_test,pred))
print(" ")
print(evaluate_metric(y_test,pred))
# Out:
# Precision Score 0.7961165048543689
# Recall Score 0.9371428571428572
# F1 Score 0.8608923884514436
# Accuracy Score 0.8233333333333334
# Roc_Auc Score 0.8005714285714286
#
#               precision    recall  f1-score   support
#
#        False       0.88      0.66      0.76       125
#         True       0.80      0.94      0.86       175
#
#     accuracy                           0.82       300
#    macro avg       0.84      0.80      0.81       300
# weighted avg       0.83      0.82      0.82       300
#
#
# [[ 83  42]
#  [ 11 164]]
#
# accuracy:82.33%
# Precision:0.80
# Recall:0.94
# f1_score:0.86
# {'accuracy': 0.82, 'Precision': 0.8, 'recall': 0.94, 'F1': 0.86}

# %%
train_scores = []
test_scores  = []

neighbors = range(1,41)

knn = KNeighborsClassifier()

for i in neighbors:
    knn.set_params(n_neighbors=i)
    knn.fit(X_train,y_train)
    train_scores.append(knn.score(X_train, y_train))
    test_scores.append(knn.score(X_test,y_test))
    
plt.plot(neighbors, train_scores, label = "Train Score")
plt.plot(neighbors, test_scores, label = "Test Score")
plt.xlabel("Number of Neighbors")
plt.ylabel("Model score")
plt.legend()
print(f"Maximum Knn score on test data : {max(test_scores)* 100:.2f}% ")
# Out:
# Maximum Knn score on test data : 42.00%

# %%
knn = KNeighborsClassifier(n_neighbors=5)
np.random.seed(42)
knn.fit(X_train,y_train)
pred = knn.predict(X_test)

print("Precision Score",precision_score(y_test,pred))
print("Recall Score",recall_score(y_test,pred))
print("F1 Score",f1_score(y_test,pred))
print("Accuracy Score",accuracy_score(y_test,pred))
print("Roc_Auc Score",roc_auc_score(y_test,pred))
print(" ")
print(classification_report(y_test,pred))
print(" ")
print(confusion_matrix(y_test,pred))
print(" ")
print(evaluate_metric(y_test,pred))
# Out:
# Precision Score 0.0
# Recall Score 0.0
# F1 Score 0.0
# Accuracy Score 0.4166666666666667
# Roc_Auc Score 0.5
#
#               precision    recall  f1-score   support
#
#        False       0.42      1.00      0.59       125
#         True       0.00      0.00      0.00       175
#
#     accuracy                           0.42       300
#    macro avg       0.21      0.50      0.29       300
# weighted avg       0.17      0.42      0.25       300
#
#
# [[125   0]
#  [175   0]]
#
# accuracy:41.67%
# Precision:0.00
# Recall:0.00
# f1_score:0.00
# {'accuracy': 0.42, 'Precision': 0.0, 'recall': 0.0, 'F1': 0.0}

# %%
xg = XGBClassifier()

np.random.seed(42)

xg.fit(X_train,y_train)
pred = xg.predict(X_test)

print("accuracy score",(accuracy_score(y_test,pred)))
print(" ")
print("F1 Score",(f1_score(y_test,pred)))
print(" ")
print("Recall Score",(recall_score(y_test,pred)))
print(" ")
print("Precision Score",(precision_score(y_test,pred)))
print(" ")
print("Classfication Report \n ",(classification_report(y_test,pred)))
print(" ")
print("Confusion Matrix \n ",(confusion_matrix(y_test,pred)))
# Out:
# [23:15:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# accuracy score 0.7766666666666666
#
# F1 Score 0.8203753351206434
#
# Recall Score 0.8742857142857143
#
# Precision Score 0.7727272727272727
#
# Classfication Report
#                 precision    recall  f1-score   support
#
#        False       0.78      0.64      0.70       125
#         True       0.77      0.87      0.82       175
#
#     accuracy                           0.78       300
#    macro avg       0.78      0.76      0.76       300
# weighted avg       0.78      0.78      0.77       300
#
#
# Confusion Matrix
#   [[ 80  45]
#  [ 22 153]]

# %%
def objective(trial: Trial,X,y):
    
    train_X,test_X,train_y,test_y = train_test_split(X, y, test_size = 0.30,random_state = 101)

    param = {
                "n_estimators" : trial.suggest_int('n_estimators', 0, 1000),
                'max_depth':trial.suggest_int('max_depth', 2, 25),
                'reg_alpha':trial.suggest_int('reg_alpha', 0, 5),
                'reg_lambda':trial.suggest_int('reg_lambda', 0, 5),
                'min_child_weight':trial.suggest_int('min_child_weight', 0, 5),
                'gamma':trial.suggest_int('gamma', 0, 5),
                'learning_rate':trial.suggest_loguniform('learning_rate',0.005,0.5),
                'colsample_bytree':trial.suggest_discrete_uniform('colsample_bytree',0.1,1,0.01),
                'nthread' : -1
            }
    model = XGBClassifier(**param)

    model.fit(train_X,train_y)

    return cross_val_score(model,test_X,test_y).mean()

# %%
study = optuna.create_study(direction='maximize',sampler=TPESampler())
study.optimize(lambda trial : objective(trial,X,y),n_trials= 20)
# Out:
# [I 2021-01-15 23:15:39,106] A new study created in memory with name: no-name-1f0fe264-e468-4ba5-af48-03ec309cc2be
# [23:15:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:15:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:15:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:15:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:15:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:16:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [I 2021-01-15 23:16:05,578] Trial 0 finished with value: 0.8200000000000001 and parameters: {'n_estimators': 772, 'max_depth': 2, 'reg_alpha': 0, 'reg_lambda': 5, 'min_child_weight': 5, 'gamma': 5, 'learning_rate': 0.023420415331458156, 'colsample_bytree': 0.89}. Best is trial 0 with value: 0.8200000000000001.
# [23:16:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:16:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:16:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:16:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:16:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:16:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [I 2021-01-15 23:16:33,045] Trial 1 finished with value: 0.8233333333333335 and parameters: {'n_estimators': 877, 'max_depth': 5, 'reg_alpha': 5, 'reg_lambda': 4, 'min_child_weight': 3, 'gamma': 0, 'learning_rate': 0.20211577446914267, 'colsample_bytree': 0.47}. Best is trial 1 with value: 0.8233333333333335.
# [23:16:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:16:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:16:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:16:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:16:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:16:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [I 2021-01-15 23:16:42,608] Trial 2 finished with value: 0.8266666666666668 and parameters: {'n_estimators': 238, 'max_depth': 10, 'reg_alpha': 4, 'reg_lambda': 3, 'min_child_weight': 2, 'gamma': 3, 'learning_rate': 0.006869010485161557, 'colsample_bytree': 0.19}. Best is trial 2 with value: 0.8266666666666668.
# [23:16:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:16:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:16:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:16:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:16:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:16:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [I 2021-01-15 23:16:56,893] Trial 3 finished with value: 0.8200000000000001 and parameters: {'n_estimators': 333, 'max_depth': 2, 'reg_alpha': 2, 'reg_lambda': 3, 'min_child_weight': 3, 'gamma': 0, 'learning_rate': 0.023373151677188144, 'colsample_bytree': 0.89}. Best is trial 2 with value: 0.8266666666666668.
# [23:16:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:16:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:16:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [I 2021-01-15 23:16:57,350] Trial 4 finished with value: 0.8266666666666668 and parameters: {'n_estimators': 4, 'max_depth': 2, 'reg_alpha': 1, 'reg_lambda': 5, 'min_child_weight': 0, 'gamma': 4, 'learning_rate': 0.033941179785023805, 'colsample_bytree': 0.47}. Best is trial 2 with value: 0.8266666666666668.
# [23:16:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:16:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:16:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:16:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:17:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:17:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:17:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:17:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:17:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [I 2021-01-15 23:17:39,087] Trial 5 finished with value: 0.8200000000000001 and parameters: {'n_estimators': 751, 'max_depth': 12, 'reg_alpha': 0, 'reg_lambda': 4, 'min_child_weight': 2, 'gamma': 2, 'learning_rate': 0.10879121894856948, 'colsample_bytree': 0.36}. Best is trial 2 with value: 0.8266666666666668.
# [23:17:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:17:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:17:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:17:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:17:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:18:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [I 2021-01-15 23:18:04,425] Trial 6 finished with value: 0.8266666666666668 and parameters: {'n_estimators': 686, 'max_depth': 3, 'reg_alpha': 0, 'reg_lambda': 3, 'min_child_weight': 2, 'gamma': 5, 'learning_rate': 0.0408580768891298, 'colsample_bytree': 0.18}. Best is trial 2 with value: 0.8266666666666668.
# [23:18:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:18:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:18:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:18:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:18:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:18:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [I 2021-01-15 23:18:32,677] Trial 7 finished with value: 0.8133333333333335 and parameters: {'n_estimators': 209, 'max_depth': 24, 'reg_alpha': 4, 'reg_lambda': 5, 'min_child_weight': 0, 'gamma': 1, 'learning_rate': 0.012259883913209845, 'colsample_bytree': 0.93}. Best is trial 2 with value: 0.8266666666666668.
# [23:18:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:18:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:18:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:18:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:18:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:18:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [I 2021-01-15 23:18:50,243] Trial 8 finished with value: 0.8233333333333335 and parameters: {'n_estimators': 302, 'max_depth': 5, 'reg_alpha': 2, 'reg_lambda': 5, 'min_child_weight': 3, 'gamma': 5, 'learning_rate': 0.03298090164884844, 'colsample_bytree': 0.63}. Best is trial 2 with value: 0.8266666666666668.
# [23:18:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:18:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:19:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:19:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:19:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:19:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [I 2021-01-15 23:19:21,441] Trial 9 finished with value: 0.8200000000000001 and parameters: {'n_estimators': 655, 'max_depth': 3, 'reg_alpha': 1, 'reg_lambda': 1, 'min_child_weight': 2, 'gamma': 3, 'learning_rate': 0.25368844951563424, 'colsample_bytree': 0.76}. Best is trial 2 with value: 0.8266666666666668.
# [23:19:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:19:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:19:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:19:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:19:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:19:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [I 2021-01-15 23:19:24,099] Trial 10 finished with value: 0.8266666666666668 and parameters: {'n_estimators': 72, 'max_depth': 14, 'reg_alpha': 4, 'reg_lambda': 1, 'min_child_weight': 5, 'gamma': 3, 'learning_rate': 0.005328053255305913, 'colsample_bytree': 0.1}. Best is trial 2 with value: 0.8266666666666668.
# [23:19:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:19:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:19:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:19:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:19:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [I 2021-01-15 23:19:25,223] Trial 11 finished with value: 0.8266666666666668 and parameters: {'n_estimators': 14, 'max_depth': 11, 'reg_alpha': 3, 'reg_lambda': 2, 'min_child_weight': 0, 'gamma': 4, 'learning_rate': 0.005032613514095269, 'colsample_bytree': 0.25}. Best is trial 2 with value: 0.8266666666666668.
# [23:19:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:19:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:19:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:19:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:19:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:19:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:19:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [I 2021-01-15 23:19:35,145] Trial 12 finished with value: 0.8266666666666668 and parameters: {'n_estimators': 139, 'max_depth': 18, 'reg_alpha': 5, 'reg_lambda': 4, 'min_child_weight': 1, 'gamma': 4, 'learning_rate': 0.009818221488126383, 'colsample_bytree': 0.44000000000000006}. Best is trial 2 with value: 0.8266666666666668.
# [23:19:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:19:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:19:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:19:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:19:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:20:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [I 2021-01-15 23:20:05,049] Trial 13 finished with value: 0.8233333333333335 and parameters: {'n_estimators': 464, 'max_depth': 8, 'reg_alpha': 3, 'reg_lambda': 0, 'min_child_weight': 1, 'gamma': 2, 'learning_rate': 0.10570662575852344, 'colsample_bytree': 0.62}. Best is trial 2 with value: 0.8266666666666668.
# [23:20:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:20:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:20:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:20:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [I 2021-01-15 23:20:05,481] Trial 14 finished with value: 0.8266666666666668 and parameters: {'n_estimators': 1, 'max_depth': 16, 'reg_alpha': 1, 'reg_lambda': 2, 'min_child_weight': 4, 'gamma': 4, 'learning_rate': 0.010842438216174286, 'colsample_bytree': 0.28}. Best is trial 2 with value: 0.8266666666666668.
# [23:20:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:20:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:20:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:20:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:20:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:20:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:20:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:20:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [I 2021-01-15 23:20:22,841] Trial 15 finished with value: 0.8266666666666668 and parameters: {'n_estimators': 448, 'max_depth': 22, 'reg_alpha': 4, 'reg_lambda': 3, 'min_child_weight': 1, 'gamma': 3, 'learning_rate': 0.07839772473934652, 'colsample_bytree': 0.1}. Best is trial 2 with value: 0.8266666666666668.
# [23:20:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:20:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:20:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:20:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:20:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:20:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [I 2021-01-15 23:20:38,942] Trial 16 finished with value: 0.8233333333333335 and parameters: {'n_estimators': 227, 'max_depth': 9, 'reg_alpha': 1, 'reg_lambda': 4, 'min_child_weight': 0, 'gamma': 4, 'learning_rate': 0.017273157245840134, 'colsample_bytree': 0.53}. Best is trial 2 with value: 0.8266666666666668.
# [23:20:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:20:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:20:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:20:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:20:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:20:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [I 2021-01-15 23:20:44,902] Trial 17 finished with value: 0.8266666666666668 and parameters: {'n_estimators': 136, 'max_depth': 16, 'reg_alpha': 3, 'reg_lambda': 2, 'min_child_weight': 4, 'gamma': 2, 'learning_rate': 0.00730638175500201, 'colsample_bytree': 0.30000000000000004}. Best is trial 2 with value: 0.8266666666666668.
# [23:20:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:20:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:20:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:20:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:20:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:21:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [I 2021-01-15 23:21:04,531] Trial 18 finished with value: 0.8266666666666668 and parameters: {'n_estimators': 478, 'max_depth': 22, 'reg_alpha': 3, 'reg_lambda': 1, 'min_child_weight': 4, 'gamma': 1, 'learning_rate': 0.08093931437372462, 'colsample_bytree': 0.14}. Best is trial 2 with value: 0.8266666666666668.
# [23:21:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:21:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:21:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:21:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:21:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:21:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [I 2021-01-15 23:21:26,181] Trial 19 finished with value: 0.8233333333333335 and parameters: {'n_estimators': 568, 'max_depth': 19, 'reg_alpha': 4, 'reg_lambda': 0, 'min_child_weight': 4, 'gamma': 1, 'learning_rate': 0.16261388424872406, 'colsample_bytree': 0.16}. Best is trial 2 with value: 0.8266666666666668.

# %%
print('Best trial: score {},\nparams {}'.format(study.best_trial.value,study.best_trial.params))
# Out:
# Best trial: score 0.8266666666666668,
# params {'n_estimators': 238, 'max_depth': 10, 'reg_alpha': 4, 'reg_lambda': 3, 'min_child_weight': 2, 'gamma': 3, 'learning_rate': 0.006869010485161557, 'colsample_bytree': 0.19}

# %%
xg_grid = XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
              colsample_bynode=1, colsample_bytree=0.22, gamma=0, gpu_id=-1,
              importance_type='gain', interaction_constraints='',
              learning_rate=0.017619976046336742, max_delta_step=0, max_depth=2,
              min_child_weight=5, missing=None, monotone_constraints='()',
              n_estimators=131, n_jobs=8, num_parallel_tree=1, random_state=0,
              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=0.5,
              tree_method='exact', validate_parameters=1, verbosity=None)

np.random.seed(42)
xg_grid.fit(X_train,y_train)
pred = xg_grid.predict(X_test)

print("Precision Score",precision_score(y_test,pred))
print("Recall Score",recall_score(y_test,pred))
print("F1 Score",f1_score(y_test,pred))
print("Accuracy Score",accuracy_score(y_test,pred))
print("Roc_Auc Score",roc_auc_score(y_test,pred))
print(" ")
print(classification_report(y_test,pred))
print(" ")
print(confusion_matrix(y_test,pred))
print(" ")
print(evaluate_metric(y_test,pred))
# Out:
# [23:21:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Precision Score 0.7792792792792793
# Recall Score 0.9885714285714285
# F1 Score 0.871536523929471
# Accuracy Score 0.83
# Roc_Auc Score 0.7982857142857143
#
#               precision    recall  f1-score   support
#
#        False       0.97      0.61      0.75       125
#         True       0.78      0.99      0.87       175
#
#     accuracy                           0.83       300
#    macro avg       0.88      0.80      0.81       300
# weighted avg       0.86      0.83      0.82       300
#
#
# [[ 76  49]
#  [  2 173]]
#
# accuracy:83.00%
# Precision:0.78
# Recall:0.99
# f1_score:0.87
# {'accuracy': 0.83, 'Precision': 0.78, 'recall': 0.99, 'F1': 0.87}

# %%
plt.style.use("default")
Classfication = [LogisticRegression(),
    RandomForestClassifier(),
    DecisionTreeClassifier(),
    GradientBoostingClassifier(),
    ExtraTreesClassifier(),
    KNeighborsClassifier(),
    SVC(C = 10,kernel='rbf',gamma=0.1),
    XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
              colsample_bynode=1, colsample_bytree=0.22, gamma=0, gpu_id=-1,
              importance_type='gain', interaction_constraints='',
              learning_rate=0.017619976046336742, max_delta_step=0, max_depth=2,
              min_child_weight=5, missing=None, monotone_constraints='()',
              n_estimators=131, n_jobs=8, num_parallel_tree=1, random_state=0,
              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=0.5,
              tree_method='exact', validate_parameters=1, verbosity=None),
    LGBMClassifier(),
    AdaBoostClassifier()]

names = []
scores = []

for clf in Classfication:
    clf = clf.fit(X_train, y_train)
    pred = clf.predict(X_test)
    
    names.append(clf.__class__.__name__)
    scores.append(accuracy_score(y_test,pred))

score_df = pd.DataFrame({'Model': names, 'Score': scores}).set_index('Model')
print(score_df)


score_df.sort_values('Score',inplace=True)
score_df.plot(kind='barh',y='Score');
# Out:
# [23:40:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#                                Score
# Model
# LogisticRegression          0.836667
# RandomForestClassifier      0.836667
# DecisionTreeClassifier      0.753333
# GradientBoostingClassifier  0.800000
# ExtraTreesClassifier        0.830000
# KNeighborsClassifier        0.416667
# SVC                         0.823333
# XGBClassifier               0.830000
# LGBMClassifier              0.803333
# AdaBoostClassifier          0.783333

# %%
Classfication = [LogisticRegression(),
    RandomForestClassifier(),
    DecisionTreeClassifier(),
    GradientBoostingClassifier(),
    ExtraTreesClassifier(),
    KNeighborsClassifier(),
    SVC(C = 10,kernel='rbf',gamma=0.1),
    XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
              colsample_bynode=1, colsample_bytree=0.22, gamma=0, gpu_id=-1,
              importance_type='gain', interaction_constraints='',
              learning_rate=0.017619976046336742, max_delta_step=0, max_depth=2,
              min_child_weight=5, missing=None, monotone_constraints='()',
              n_estimators=131, n_jobs=8, num_parallel_tree=1, random_state=0,
              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=0.5,
              tree_method='exact', validate_parameters=1, verbosity=None),
    LGBMClassifier(),
    AdaBoostClassifier()]

names = []
scores = []

for clf in Classfication:
    clf = clf.fit(X_train, y_train)
    pred = clf.predict(X_test)
    
    names.append(clf.__class__.__name__)
    scores.append(f1_score(y_test,pred))

score_df = pd.DataFrame({'Model': names, 'Score': scores}).set_index('Model')
print(score_df)


score_df.sort_values('Score',inplace=True)
score_df.plot(kind='barh',y='Score');
# Out:
# [23:40:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#                                Score
# Model
# LogisticRegression          0.877193
# RandomForestClassifier      0.870886
# DecisionTreeClassifier      0.775862
# GradientBoostingClassifier  0.850394
# ExtraTreesClassifier        0.871537
# KNeighborsClassifier        0.000000
# SVC                         0.860892
# XGBClassifier               0.871537
# LGBMClassifier              0.841823
# AdaBoostClassifier          0.821918

# %%
Classfication = [LogisticRegression(),
    RandomForestClassifier(),
    DecisionTreeClassifier(),
    GradientBoostingClassifier(),
    ExtraTreesClassifier(),
    KNeighborsClassifier(),
    SVC(C = 10,kernel='rbf',gamma=0.1),
    XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
              colsample_bynode=1, colsample_bytree=0.22, gamma=0, gpu_id=-1,
              importance_type='gain', interaction_constraints='',
              learning_rate=0.017619976046336742, max_delta_step=0, max_depth=2,
              min_child_weight=5, missing=None, monotone_constraints='()',
              n_estimators=131, n_jobs=8, num_parallel_tree=1, random_state=0,
              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=0.5,
              tree_method='exact', validate_parameters=1, verbosity=None),
    LGBMClassifier(),
    AdaBoostClassifier()]

names = []
scores = []

for clf in Classfication:
    clf = clf.fit(X_train, y_train)
    pred = clf.predict(X_test)
    
    names.append(clf.__class__.__name__)
    scores.append(precision_score(y_test,pred))

score_df = pd.DataFrame({'Model': names, 'Score': scores}).set_index('Model')
print(score_df)


score_df.sort_values('Score',inplace=True)
score_df.plot(kind='barh',y='Score');
# Out:
# [23:40:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#                                Score
# Model
# LogisticRegression          0.781250
# RandomForestClassifier      0.782805
# DecisionTreeClassifier      0.783333
# GradientBoostingClassifier  0.783654
# ExtraTreesClassifier        0.780269
# KNeighborsClassifier        0.000000
# SVC                         0.796117
# XGBClassifier               0.779279
# LGBMClassifier              0.792929
# AdaBoostClassifier          0.813187

# %%
Classfication = [LogisticRegression(),
    RandomForestClassifier(),
    DecisionTreeClassifier(),
    GradientBoostingClassifier(),
    ExtraTreesClassifier(),
    KNeighborsClassifier(),
    SVC(C = 10,kernel='rbf',gamma=0.1),
    XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
              colsample_bynode=1, colsample_bytree=0.22, gamma=0, gpu_id=-1,
              importance_type='gain', interaction_constraints='',
              learning_rate=0.017619976046336742, max_delta_step=0, max_depth=2,
              min_child_weight=5, missing=None, monotone_constraints='()',
              n_estimators=131, n_jobs=8, num_parallel_tree=1, random_state=0,
              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=0.5,
              tree_method='exact', validate_parameters=1, verbosity=None),
    LGBMClassifier(),
    AdaBoostClassifier()]

names = []
scores = []

for clf in Classfication:
    clf = clf.fit(X_train, y_train)
    pred = clf.predict(X_test)
    
    names.append(clf.__class__.__name__)
    scores.append(recall_score(y_test,pred))

score_df = pd.DataFrame({'Model': names, 'Score': scores}).set_index('Model')
print(score_df)


score_df.sort_values('Score',inplace=True)
score_df.plot(kind='barh',y='Score');
# Out:
# [23:41:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#                                Score
# Model
# LogisticRegression          1.000000
# RandomForestClassifier      0.982857
# DecisionTreeClassifier      0.777143
# GradientBoostingClassifier  0.902857
# ExtraTreesClassifier        0.988571
# KNeighborsClassifier        0.000000
# SVC                         0.937143
# XGBClassifier               0.988571
# LGBMClassifier              0.897143
# AdaBoostClassifier          0.845714

# %%
log = LogisticRegression()
np.random.seed(42)
log.fit(X_train,y_train)
pred = log.predict(X_test)
show_All_scores(log)
# Out:
#  Training f1_score
#  0.88
#
#  	 Testing f1_score
#  0.8771929824561403
#
#  Training precision_score
#  0.7872763419483101
#
#  	 Testing precision_score
#  0.78125
#
#  Training recall_score
#  0.9974811083123426
#
#  	 Testing recall_score
#  1.0
#
#  Training accuracy_score
#  0.8457142857142858
#
#  	 Testing accuracy_score
#  0.8366666666666667
#
#  Training roc_auc_score
#  0.8221728973904948
#
#  	 Testing roc_auc_score
#  0.804

# %%
df = pd.read_json('data.json')

# %%
df2 = pd.json_normalize(df['req'])

# %%
import spacy
import re
import spacy
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
import re
from string import punctuation
import en_core_web_sm

nlp = en_core_web_sm.load()

stop_words = ['the','a','an','and','but','if','or','because','as','what','which','this','that','these','those','then',
              'just','so','than','such','both','through','about','for','is','of','while','during','to','What','Which',
              'Is','If','While','This']

def text_to_wordlist(text, remove_stop_words=True, stem_words=False):
   

  
    text = re.sub(r"[^A-Za-z0-9]", " ", text)
    text = re.sub(r"what's", "", text)
    text = re.sub(r"What's", "", text)
    text = re.sub(r"\'s", " ", text)
    text = re.sub(r"\'ve", " have ", text)
    text = re.sub(r"can't", "cannot ", text)
    text = re.sub(r"n't", " not ", text)
    text = re.sub(r"I'm", "I am", text)
    text = re.sub(r" m ", " am ", text)
    text = re.sub(r"\'re", " are ", text)
    text = re.sub(r"\'d", " would ", text)
    text = re.sub(r"\'ll", " will ", text)
    text = re.sub(r"60k", " 60000 ", text)
    text = re.sub(r" e g ", " eg ", text)
    text = re.sub(r" b g ", " bg ", text)
    text = re.sub(r"\0s", "0", text)
    text = re.sub(r" 9 11 ", "911", text)
    text = re.sub(r"e-mail", "email", text)
    text = re.sub(r"\s{2,}", " ", text)
    text = re.sub(r"quikly", "quickly", text)
    text = re.sub(r" usa ", " America ", text)
    text = re.sub(r" USA ", " America ", text)
    text = re.sub(r" u s ", " America ", text)
    text = re.sub(r" uk ", " England ", text)
    text = re.sub(r" UK ", " England ", text)
    text = re.sub(r"india", "India", text)
    text = re.sub(r"switzerland", "Switzerland", text)
    text = re.sub(r"china", "China", text)
    text = re.sub(r"chinese", "Chinese", text) 
    text = re.sub(r"imrovement", "improvement", text)
    text = re.sub(r"intially", "initially", text)
    text = re.sub(r"quora", "Quora", text)
    text = re.sub(r" dms ", "direct messages ", text)  
    text = re.sub(r"demonitization", "demonetization", text) 
    text = re.sub(r"actived", "active", text)
    text = re.sub(r"kms", " kilometers ", text)
    text = re.sub(r"KMs", " kilometers ", text)
    text = re.sub(r" cs ", " computer science ", text) 
    text = re.sub(r" upvotes ", " up votes ", text)
    text = re.sub(r" iPhone ", " phone ", text)
    text = re.sub(r"\0rs ", " rs ", text) 
    text = re.sub(r"calender", "calendar", text)
    text = re.sub(r"ios", "operating system", text)
    text = re.sub(r"gps", "GPS", text)
    text = re.sub(r"gst", "GST", text)
    text = re.sub(r"programing", "programming", text)
    text = re.sub(r"bestfriend", "best friend", text)
    text = re.sub(r"dna", "DNA", text)
    text = re.sub(r"III", "3", text) 
    text = re.sub(r"the US", "America", text)
    text = re.sub(r"Astrology", "astrology", text)
    text = re.sub(r"Method", "method", text)
    text = re.sub(r"Find", "find", text) 
    text = re.sub(r"banglore", "Banglore", text)
    text = re.sub(r" J K ", " JK ", text)
    
   
    text = ''.join([c for c in text if c not in punctuation])
    
   
    if remove_stop_words:
        text = text.split()
        text = [w for w in text if not w in stop_words]
        text = " ".join(text)
    
   
    if stem_words:
        text = text.split()
        stemmer = SnowballStemmer('english')
        stemmed_words = [stemmer.stem(word) for word in text]
        text = " ".join(stemmed_words)
    
   
    return(text)

# %%
#df2['baseUrl'] = df2['baseUrl'].apply(lambda x:text_to_wordlist(x))

# %%
def getTokens(input):
    tokensBySlash = str(input.encode('utf-8')).split('/')
    allTokens=[]
    for i in tokensBySlash:
        tokens = str(i).split('-')
        tokensByDot = []
        for j in range(0,len(tokens)):
            tempTokens = str(tokens[j]).split('.')
            tokentsByDot = tokensByDot + tempTokens
        allTokens = allTokens + tokens + tokensByDot
    allTokens = list(set(allTokens))
    if 'com' in allTokens:
        allTokens.remove('com')
    return allTokens

vectorizer = TfidfVectorizer( tokenizer=getTokens ,use_idf=True, smooth_idf=True, sublinear_tf=False)
features = vectorizer.fit_transform(df2['baseUrl']).toarray()

# %%
y= df['isSafe']

# %%
X_train, X_test, y_train, y_test = train_test_split(features, y, test_size=0.3, random_state=100)

# %%
log = LogisticRegression()
np.random.seed(42)
log.fit(X_train,y_train)
pred = log.predict(X_test)

# %%
X_predict = ['/crm/note']
X_predict = vectorizer.transform(X_predict)
y_Predict = log.predict(X_predict)
print(y_Predict)
# Out:
# [ True]
